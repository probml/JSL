# %%
import sys
sys.path.append("../")

# %% [markdown]
# # EKF v.s. UKF demo

# %%
from jsl.scripts import ekf_vs_ukf

# %%
f_main, f_ekf, f_ukf = ekf_vs_ukf.main()

# %% [markdown]
# # EEKF

# %%
import sys
sys.path.append("..")

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from jsl.scripts import eekf_logistic_regression_demo

# %%
figs = eekf_logistic_regression_demo.main()
# Out:
# EEKF weights
# [-2.4149106   0.93760556  0.9827975 ]
#
# Laplace weights
# [-2.2504709   0.9534859   0.99923253]
